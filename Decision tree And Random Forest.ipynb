# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Education : 1 'Below College' , 2 'College' , 3 'Bachelor', 4 'Master' , 5 'Doctor'
#
# Environment Satisfaction : 1 'Low', 2 'Medium', 3 'High', 4 'Very High'
#
# Job Involvement : 1 'Low' , 2 'Medium', 3 'High' , 4 'Very High'
#
# Job Satisfaction : 1 'Low' , 2 'Medium' , 3 'High' , 4 'Very High'
#
# Performance Rating : 1 'Low' , 2 'Good' , 3 'Excellent' , 4 'Outstanding'
#
# Relationship Satisfaction : 1 'Low' , 2 'Medium' , 3 'High' , 4 'Very High'
#
# WorkLife Balance : 1 'Bad' , 2 'Good' , 3 'Better' , 4 'Best'

# %%
df = pd.read_csv('employee.csv')
pd.set_option('display.max_columns',100)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.boxplot(df['MonthlyIncome']);

# %%
sns.boxplot(df['Age']);

# %%
sns.boxplot(df['MonthlyRate']);

# %%
df['MonthlyIncome'].hist(bins=50) # MonthlyIncome is skewed so we can go IQR

# %%
IQR = df['MonthlyIncome'].quantile(0.75) - df['MonthlyIncome'].quantile(0.25)
UL = IQR + 1.5*(df['MonthlyIncome'].quantile(0.75))
LL = IQR - 1.5*(df['MonthlyIncome'].quantile(0.25))
print('Value of Outlier', UL,   LL)
# Out:
# Value of Outlier 18036.5 1101.5

# %%
df.loc[df['MonthlyIncome']>18036]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 25     53        No      Travel_Rarely       1282  Research & Development
# 29     46        No      Travel_Rarely        705                   Sales
# 45     41       Yes      Travel_Rarely       1360  Research & Development
# 62     50        No      Travel_Rarely        989  Research & Development
# 105    59        No         Non-Travel       1420         Human Resources
# ...   ...       ...                ...        ...                     ...
# 1331   48        No      Travel_Rarely       1224  Research & Development
# 1377   49        No  Travel_Frequently       1064  Research & Development
# 1401   55        No      Travel_Rarely        189         Human Resources
# 1437   39        No         Non-Travel        105  Research & Development
# 1443   42        No      Travel_Rarely        300  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.loc[df['MonthlyIncome']<1101]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 513    20       Yes      Travel_Rarely       1362  Research & Development
# 727    18        No         Non-Travel        287  Research & Development
# 764    28        No      Travel_Rarely       1144                   Sales
# 1338   30       Yes      Travel_Rarely        945                   Sales
# 1365   29       Yes  Travel_Frequently        746                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 513                 10          1           Medical              1
# 727                  5          2     Life Sciences              1
# 764                 10          1           Medical              1
# 1338                 9          3           Medical              1
# 1365                24          3  Technical Degree              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# ...

# %%
df.drop(df.loc[df['MonthlyIncome']>18036].index,inplace=True)
df.drop(df.loc[df['MonthlyIncome']<1101].index,inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#df.loc[df['Over18']=='Y','Over18']=1
#df.loc[df['Attrition']=='No','Attrition'] = 0
#df.loc[df['Attrition']=='Yes','Attrition'] = 1

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Attrition']=lb.fit_transform(df['Attrition'])

# %%
df_num = df[df.select_dtypes(include=np.number).columns]
df_cat = df[df.select_dtypes(include='object').columns]
df_dummy= pd.get_dummies(df_cat,drop_first=True)# drop first equal true
data =pd.concat([df_num,df_dummy],axis=1)
data.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   41          1       1102                 1          2              1
# 1   49          0        279                 8          1              1
# 2   37          1       1373                 2          2              1
# 3   33          0       1392                 3          4              1
# 4   27          0        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0               1                        2          94               3
# 1               2                        3          61               2
# 2               4                        4          92               2
# 3               5                        4          56               3
# 4               7                        1          40               3
#
#    JobLevel  JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# ...

# %%
data.shape
# Out:
# (1396, 48)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Male',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
# ...

# %%
x = data.drop(['Attrition'],axis=1)
y =data['Attrition']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=8)
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8353221957040573

# %%
import statsmodels.api as sm

# %%
logit_model=sm.Logit(y,x)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.299266
#          Iterations 8
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1396
# Model:                          Logit   Df Residuals:                     1373
# Method:                           MLE   Df Model:                           22
# Date:                Fri, 24 Jul 2020   Pseudo R-squ.:                  0.3295
# Time:                        22:40:44   Log-Likelihood:                -417.78
# converged:                       True   LL-Null:                       -623.05
# Covariance Type:            nonrobust   LLR p-value:                 2.734e-73
# ...
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# C:\Users\Ashish\Anaconda3\envs\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nsmallest(12).plot(kind='barh')
plt.show()

# %%
feat_importances.nlargest(12).plot(kind='barh');

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=8)
dt1 = DecisionTreeClassifier(criterion='entropy',max_depth=3)
dt1.fit(x_train,y_train)
y_pred = dt1.predict(x_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8400954653937948

# %%
import graphviz

# %%
from sklearn.externals.six import StringIO

# %%
from IPython.display import Image

# %%
import pydotplus
import pydot

# %%
from sklearn.tree import export_graphviz

# %%
dot_data = StringIO()
export_graphviz(dt, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graphviz.graph_from_dot_data(dot_data.getvalue())

# %%
Image(graph.create_png())

# %%
importances = pd.DataFrame({'feature':x_train.columns,'importance':np.round(model.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)

# %%
importances
# Out:
#                               feature  importance
# 0                                 Age       0.079
# 22                       OverTime_Yes       0.068
# 12               YearsWithCurrManager       0.061
# 4                            JobLevel       0.059
# 2             EnvironmentSatisfaction       0.057
# 5                     JobSatisfaction       0.056
# 1                    DistanceFromHome       0.055
# 6                  NumCompaniesWorked       0.051
# 3                      JobInvolvement       0.051
# 11            YearsSinceLastPromotion       0.048
# 8               TrainingTimesLastYear       0.048
# 7            RelationshipSatisfaction       0.048
# 10                 YearsInCurrentRole       0.045
# 9                     WorkLifeBalance       0.044
# 21               MaritalStatus_Single       0.044
# 18                        Gender_Male       0.040
# 13   BusinessTravel_Travel_Frequently       0.029
# 20      JobRole_Laboratory Technician       0.026
# ...

# %%
max_depth_range = list(range(1, 6))
accuracy = []
for depth in max_depth_range:
    dt = DecisionTreeClassifier(max_depth = depth,random_state = 0)
    dt.fit(x_train,y_train)
    score = dt.score(x_test, y_test)
    accuracy.append(score)

# %%
accuracy
# Out:
# [0.8281622911694511,
#  0.8281622911694511,
#  0.8353221957040573,
#  0.8305489260143198,
#  0.8329355608591885]

# %%
from sklearn import tree
plt.figure(figsize=(40,16))
tree.plot_tree(dt1,feature_names=x_train.columns.values);
#plt.savefig('sampleTree.jpeg')

# %%
col_importance = pd.concat([pd.Series(x_train.columns),pd.Series(model.feature_importances_)],axis=1,keys=['Column','Coefficient'])
col_importance.sort_values(by='Coefficient',ascending=False).head(5)
# Out:
#                      Column  Coefficient
# 0                       Age     0.079190
# 22             OverTime_Yes     0.067858
# 12     YearsWithCurrManager     0.061024
# 4                  JobLevel     0.058743
# 2   EnvironmentSatisfaction     0.057442

# %%
from sklearn.metrics import roc_auc_score,roc_curve
roc_auc = roc_auc_score(y_test,y_pred)

# %%
roc_auc
# Out:
# 0.5842539225104066

# %%
fpr, tpr, thresholds = roc_curve(y_test, dt1.predict_proba(x_test)[:,1])
plt.plot(fpr,tpr)

# %% [markdown]
# ## Decision Tree Implemnetation

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier(criterion='entropy',
                                    max_depth=1,class_weight='balanced',random_state=15)
## case of under fitting of data
model.fit(x_train,y_train)
y_pred_test = model.predict(x_test)
y_pred_train = model.predict(x_train)
print("Accuracy:",accuracy_score(y_test, y_pred_test))
print("Accuracy:",accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.7136038186157518
# Accuracy: 0.7338792221084954

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier(criterion='entropy',
                                    class_weight='balanced',random_state=15)
## case of over fitting of data
model.fit(x_train,y_train)
y_pred_test = model.predict(x_test)
y_pred_train = model.predict(x_train)
print("Accuracy:",accuracy_score(y_test, y_pred_test))
print("Accuracy:",accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.7852028639618138
# Accuracy: 1.0

# %% [markdown]
# ## Random Forest

# %%
from sklearn import *
rf = ensemble.RandomForestClassifier(n_estimators=150,criterion='entropy',
                                    class_weight='balanced',max_leaf_nodes=12,random_state=15)

rf.fit(x_train,y_train)
y_pred_test = rf.predict(x_test)
y_pred_train = rf.predict(x_train)
print("Accuracy:",accuracy_score(y_test, y_pred_test))
print("Accuracy:",accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.8114558472553699
# Accuracy: 0.8771750255885363

# %% [markdown]
# ## RandomSearchCV

# %%
param = {'n_estimators':[140,145,150,155,160],
        'max_leaf_nodes':range(10,20),
        'criterion':['gini','entropy']}

# %%
rf = ensemble.RandomForestClassifier(random_state=15)

# %%
from sklearn.model_selection import RandomizedSearchCV
rms = RandomizedSearchCV(rf,param,n_iter=10,cv=3,random_state=15)

# %%
rms_result = rms.fit(x_train, y_train)

# %%
y_pred_test = rms_result.predict(x_test)
y_pred_train = rms_result.predict(x_train)
print("Accuracy:",accuracy_score(y_test, y_pred_test))
print("Accuracy:",accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.8448687350835322
# Accuracy: 0.8628454452405322

# %%
from sklearn.model_selection import GridSearchCV
gs =GridSearchCV(rf,param,cv=3)

# %%
gs_result = gs.fit(x_train, y_train)

# %%
y_pred_test = gs_result.predict(x_test)
y_pred_train = gs_result.predict(x_train)
print("Accuracy:",accuracy_score(y_test, y_pred_test))
print("Accuracy:",accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.8448687350835322
# Accuracy: 0.8536335721596725
